# %% [markdown]
# # SWD in WI
# Heute beginnen wir langsam
# $e = mc^2$

# %%
netto_preis = 15.0
brutto_preis = 1.2 * netto_preis
print(brutto_preis)
# Out:
# 18.0

# %%
import numpy as np

import matplotlib.pyplot as plt

x = np.linspace(-10, 10, 400)
y = x**2

plt.plot(x, y)
plt.xlabel('x')
plt.ylabel('x^2')
plt.title('Plot of x^2')
plt.grid(True)
plt.show()
